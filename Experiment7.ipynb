# %% [markdown]
# # Experiment 7: J Functions

# %% [markdown]
# ### 1. Write a Python function to find the maximum and minimum numbers from a sequence of numbers. (Note: Do not use built-in functions.)

# %%
def find_limits(arr):
    mx = mn = arr[0]
    for x in arr:
        if x > mx: mx = x
        if x < mn: mn = x
    return mx, mn

nums = list(map(int, input("Enter numbers: ").split()))
print("Entered list: ", nums)
print("Result (Max, Min): ", find_limits(nums))
# Out:
# Entered list:  [10, 6, 5, 28, 19]
# Result (Max, Min):  (28, 5)

# %% [markdown]
# ### 2. Write a Python function that takes a positive integer and returns the sum of the cube of all the positive integers smaller than the specified number.

# %%
def sum_of_cubes(n):
    total = 0
    for i in range(1, n):
        total += i**3
    return total

num = int(input("Enter a positive integer: "))
print("Input is: ", num)
print("Sum of cubes:", sum_of_cubes(num))
# Out:
# Input is:  5
# Sum of cubes: 100

# %% [markdown]
# ### 3. Write a Python function to print 1 to n using recursion. (Note: Do not use loop)

# %%
def show(n):
    if n == 0: return
    show(n-1)
    print(n, end=" ")

num = int(input("Enter n: "))
print("Entered number is: ", num)
show(num)
# Out:
# Entered number is:  5
# 1 2 3 4 5

# %% [markdown]
# ### 4. Write a recursive function to print Fibonacci series upto n terms.

# %%
def fib(n):
    return n if n < 2 else fib(n-1) + fib(n-2)

n = int(input("Enter terms: "))
print("Input: ", n)
print(*(fib(i) for i in range(n)))
# Out:
# Input:  6
# 0 1 1 2 3 5

# %% [markdown]
# ### 5. Write a lambda function to find volume of cone.

# %%
cone = lambda r,h: (1/3)*3.14*r*r*h
print(cone(3,5))
# Out:
# 47.099999999999994

# %% [markdown]
# ### 6. Write a lambda function which gives tuple of max and min from a list.
# ### Sample input: [10, 6, 8, 90, 12, 56]
# ### Sample output: (90,6)

# %%
f = lambda x: (max(x), min(x))
print(f([10,6,8,90,12,56]))
# Out:
# (90, 6)

# %% [markdown]
# ### 7. Write functions to explain mentioned concepts:
# ### a. Keyword argument
# ### b. Default argument
# ### c. Variable length argument

# %%
def info(name, city):
    print(name, "from", city)
info(city="Delhi", name="Hitesh")
# Out:
# Hitesh from Delhi

# %%
def greet(name="Guest"):
    print("Hello", name)

greet()
greet("Hitesh")
# Out:
# Hello Guest
# Hello Hitesh

# %%
def total(*nums):
    print(sum(nums))

total(1,2,3)
total(5,10,15,20)
# Out:
# 6
# 50
