# %% [markdown]
# # Experiment 5: String and Sets

# %% [markdown]
# ### 1. Write a program to count and display the number of capital letters in a given string

# %%
text = input("Enter text: ")
vowel_list = [ch for ch in text if ch.lower() in "aeiou"]
print("Total vowels =", len(vowel_list))
# Out:
# Total vowels = 5

# %% [markdown]
# ### 2. Count total number of vowels in a given string.

# %%
text = input("Enter a string: ")

vowels = "aeiouAEIOU"

vowel_count = 0

for ch in text:
    if ch in vowels:
        vowel_count += 1

print("Total number of vowels =", vowel_count)
# Out:
# Total number of vowels = 4

# %% [markdown]
# ### 3. Input a sentence and print words in separate lines.

# %%
n = input("Enter a sentence: ")
words = n.split() 
for word in words:
    print(word)
# Out:
# Hey
# I
# am
# Hitesh

# %% [markdown]
# ### 4. WAP to enter a string and a substring. You have to print the number of times
# ### that the substring occurs in the given string. String traversal will take place from
# ### left to right, not from right to left.
# ### Sample Input
# ### ABCDCDC
# ### CDC
# ### Sample Output
# ### 2

# %%
main = input("Enter main string: ")
sub = input("Enter substring: ")

i = 0
count = 0

while i <= len(main) - len(sub):
    if main[i:i+len(sub)] == sub:
        count += 1
    i += 1

print("Main string :", main)
print("Substring:", sub)
print("Total occurrences:", count)
# Out:
# Main string : ABCDCDC
# Substring: CDC
# Total occurrences: 2

# %% [markdown]
# ### 5. Given a string containing both upper and lower-case alphabets. Write a Python
# ### program to count the number of occurrences of each alphabet (case
# ### insensitive) and display the same.
# ### Sample Input
# ### ABaBCbGc
# ### Sample Output
# ### 2A
# ### 3B
# ### 2C
# ### 1G

# %%
text = input("Enter text: ").upper()

freq = {}

for ch in text:
    if ch.isalpha():
        freq[ch] = freq.get(ch, 0) + 1

for key in sorted(freq):
    print("Given string: ", text)
    print(freq[key], key, sep="")
# Out:
# Given string:  ABABCDGC
# 2A
# Given string:  ABABCDGC
# 2B
# Given string:  ABABCDGC
# 2C
# Given string:  ABABCDGC
# 1D
# Given string:  ABABCDGC
# 1G

# %% [markdown]
# ### 6. Program to count the number of unique words in a given sentence using sets.

# %%
sentence = input("Enter sentence: ")
unique = {word.strip() for word in sentence.split()}
print("Unique word count:", len(unique))
# Out:
# Unique word count: 3

# %% [markdown]
# ### 7. Create 2 sets s1 and s2 of n fruits each by taking input from user and find:
# ### a. Fruits which are in both sets s1 and s2
# ### b. Fruits only in s1 but not in s2
# ### c. Count of all fruits from s1 and s2

# %%
n = int(input("Enter number of fruits: "))

print("Enter fruits for set 1:")
list1 = [input() for _ in range(n)]

print("Enter fruits for set 2:")
list2 = [input() for _ in range(n)]

s1 = set(list1)
s2 = set(list2)

print("Common:", s1 & s2)

print("Only in set1:", s1 - s2)

print("Total fruits:", len(s1 | s2))
# Out:
# Enter fruits for set 1:
# Enter fruits for set 2:
# Common: set()
# Only in set1: {'Apple banana mango', 'Grapes banana apple'}
# Total fruits: 3

# %% [markdown]
# ### 8. Take two sets and apply various set operations on them:
# ### S1 = {Red, yellow, orange, blue}
# ### S2 = {violet, blue, purple}

# %%
S1 = {"Red", "Yellow", "Orange", "Blue"}
S2 = {"Violet", "Blue", "Purple"}

print("Union ->", S1 | S2)

print("Intersection ->", S1 & S2)

print("S1 - S2 ->", S1 - S2)
print("S2 - S1 ->", S2 - S1)

print("Symmetric Difference ->", S1 ^ S2)
# Out:
# Union -> {'Red', 'Orange', 'Violet', 'Blue', 'Yellow', 'Purple'}
# Intersection -> {'Blue'}
# S1 - S2 -> {'Red', 'Orange', 'Yellow'}
# S2 - S1 -> {'Purple', 'Violet'}
# Symmetric Difference -> {'Red', 'Orange', 'Violet', 'Yellow', 'Purple'}
