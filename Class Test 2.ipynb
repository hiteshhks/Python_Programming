# %% [markdown]
# Ques 1. Class Variable vs Instance Variable

# %%
class Student:
    school_name = "UPES"   
    def __init__(self, name, age):
        self.name = name
        self.age = age

s1 = Student("Hitesh", 21)
s2 = Student("Viraj", 19)

print("School:", Student.school_name)
print("Student 1:", s1.name, s1.age)
print("Student 2:", s2.name, s2.age)
# Out:
# School: UPES
# Student 1: Hitesh 21
# Student 2: Viraj 19

# %% [markdown]
# Q3. Static Method

# %%
class MathHelper:

    @staticmethod
    def is_even(num):
        return num % 2 == 0
    
print(MathHelper.is_even(8))
print(MathHelper.is_even(11))
# Out:
# True
# False

# %% [markdown]
# Q4. Public and Private Data Members

# %%
class BankAccount:
    def __init__(self, name, balance):
        self.name = name
        self.__balance = balance   # private

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient balance")

    def show_balance(self):
        print("Balance:", self.__balance)

acc = BankAccount("Hitesh", 1000)

acc.deposit(500)
acc.show_balance()

acc.withdraw(300)
acc.show_balance()

acc.withdraw(2000)
# Out:
# Balance: 1500
# Balance: 1200
# Insufficient balance

# %% [markdown]
# Q5. Built-in Class Attributes

# %%
class Student:
    """This is Student class"""
    
print(Student.__name__)
print(Student.__doc__)
print(Student.__module__)
print(Student.__dict__)
# Out:
# Student
# This is Student class
# __main__
# {'__module__': '__main__', '__firstlineno__': 1, '__doc__': 'This is Student class', '__static_attributes__': (), '__dict__': <attribute '__dict__' of 'Student' objects>, '__weakref__': <attribute '__weakref__' of 'Student' objects>}

# %% [markdown]
# Q6. Magic Methods / Operator Overloading

# %%
class Product:
    def __init__(self, name, price):
        self.name = name
        self.price = price

    def __str__(self):
        return f"Product: {self.name}, Price: {self.price}"

    def __add__(self, other):
        return self.price + other.price

    def __eq__(self, other):
        return self.price == other.price

p1 = Product("Laptop", 50000)
p2 = Product("Phone", 30000)
p3 = Product("Tablet", 50000)

print(p1)
print(p1 + p2)
print(p1 == p3)
print(p1 == p2)
# Out:
# Product: Laptop, Price: 50000
# 80000
# True
# False
